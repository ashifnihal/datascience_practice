# %%
import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
flower_data = pd.read_csv(r"C:\Users\ashif\datascience_notebooks\Iris.csv")

# %%
flower_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
flower_data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
flower_data["Species"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
flower_data["Species"] = flower_data.Species.astype('category')

# %%
flower_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    category
# dtypes: category(1), float64(4), int64(1)
# memory usage: 6.3 KB

# %%
flower_data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
flower_data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
flower_data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
sepal_data = plt.scatter(flower_data.SepalWidthCm, flower_data.SepalLengthCm, c="red")

# %%
petal_data = plt.scatter(flower_data.PetalWidthCm, flower_data.PetalLengthCm, c="Green")

# %%
petal_data = sns.scatterplot(x=flower_data.PetalWidthCm, y=flower_data.PetalLengthCm, c="Green", hue=flower_data.Species)

# %%
sepal_data = sns.scatterplot(x=flower_data.SepalWidthCm, y=flower_data.SepalLengthCm, hue=flower_data.Species)

# %%
flower_data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sepel_data_1 = flower_data.copy()

# %%
sepel_data_1 = sepel_data_1.drop(columns=["PetalLengthCm", "PetalWidthCm"])

# %%
sepel_data_1.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm      Species
# 0   1            5.1           3.5  Iris-setosa
# 1   2            4.9           3.0  Iris-setosa
# 2   3            4.7           3.2  Iris-setosa
# 3   4            4.6           3.1  Iris-setosa
# 4   5            5.0           3.6  Iris-setosa

# %%
petal_data_1 = flower_data.copy()

# %%
petal_data_1 = petal_data_1.drop(columns=["SepalLengthCm", "SepalWidthCm"])

# %%
petal_data_1.head()
# Out:
#    Id  PetalLengthCm  PetalWidthCm      Species
# 0   1            1.4           0.2  Iris-setosa
# 1   2            1.4           0.2  Iris-setosa
# 2   3            1.3           0.2  Iris-setosa
# 3   4            1.5           0.2  Iris-setosa
# 4   5            1.4           0.2  Iris-setosa

# %%
petal_data_graph = sns.scatterplot(data=petal_data_1, x=petal_data_1.PetalWidthCm, y=petal_data_1.PetalLengthCm, hue=petal_data_1.Species)

# %%
sepal_data_graph = sns.scatterplot(data=sepel_data_1, x="SepalWidthCm", y="SepalLengthCm", hue="Species")

# %%
flower_data[flower_data.SepalWidthCm<flower_data.PetalWidthCm]
# Out:
# Empty DataFrame
# Columns: [Id, SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm, Species]
# Index: []

# %%
flower_data[flower_data.PetalLengthCm>flower_data.SepalLengthCm]
# Out:
# Empty DataFrame
# Columns: [Id, SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm, Species]
# Index: []

# %%
flower_data[flower_data.PetalLengthCm==flower_data.SepalLengthCm]
# Out:
# Empty DataFrame
# Columns: [Id, SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm, Species]
# Index: []

# %%
flower_data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
flower_data_new = flower_data.drop(columns=['Id'])

# %%
flower_data_new.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.countplot(data=flower_data_new)
# Out:
# <Axes: ylabel='count'>

# %%
flower_data_new.Species.value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
sns.jointplot(y=flower_data_new.SepalWidthCm, x=flower_data_new.SepalLengthCm, data=flower_data_new)

# %%
sns.jointplot(x="SepalWidthCm", y="SepalLengthCm", data=flower_data_new, kind='reg')

# %%
sns.jointplot(x="SepalWidthCm", y="SepalLengthCm", data=flower_data_new, kind='scatter')

# %%
sns.jointplot(x="SepalWidthCm", y="SepalLengthCm", data=flower_data_new, kind='kde')

# %%
sns.jointplot(x="SepalWidthCm", y="SepalLengthCm", data=flower_data_new, kind='hist')

# %%
sns.jointplot(x="SepalWidthCm", y="SepalLengthCm", data=flower_data_new, kind='hex')

# %%
flower_data_new.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
fg1 = sns.FacetGrid(data=flower_data_new, col="Species", row="SepalLengthCm", hue="Species")
fg1.map(sns.scatterplot, "SepalLengthCm", "PetalLengthCm")
fg1.map(sns.scatterplot, "SepalWidthCm", "PetalWidthCm")

# %%
fig2 = sns.FacetGrid(data=flower_data_new, hue="Species").map(sns.scatterplot, "PetalLengthCm", "PetalWidthCm").add_legend()

# %%
fig3 = sns.FacetGrid(data=flower_data_new, hue="Species").map(sns.scatterplot, "SepalLengthCm", "SepalWidthCm").add_legend()

# %%
fig = plt.gcf()
fig.set_size_inches(12, 7)
sns.boxplot(data=flower_data_new, x="Species", y="PetalLengthCm", orient='v', dodge=False)
# Out:
# <Axes: xlabel='Species', ylabel='PetalLengthCm'>

# %%
flower_data_new.boxplot(by="Species", figsize=(12,6))
# Out:
# array([[<Axes: title={'center': 'PetalLengthCm'}, xlabel='[Species]'>,
#         <Axes: title={'center': 'PetalWidthCm'}, xlabel='[Species]'>],
#        [<Axes: title={'center': 'SepalLengthCm'}, xlabel='[Species]'>,
#         <Axes: title={'center': 'SepalWidthCm'}, xlabel='[Species]'>]],
#       dtype=object)

# %%
fig2 = plt.gcf()
fig2.set_size_inches(12, 6)
fig2 = sns.stripplot(data=flower_data_new, x="Species", y="SepalLengthCm", jitter=True, orient='v', edgecolor='gray', palette='winter', size=8)

# %%
fig = plt.gcf()
fig.set_size_inches(12, 7)
fig=sns.boxplot(data=flower_data_new, x="Species", y="SepalLengthCm")
fig = sns.stripplot(data=flower_data_new, x="Species", y="SepalLengthCm", hue="Species")

# %%
fig = plt.gcf()
fig.set_size_inches(10, 7)
fig = sns.violinplot(data=flower_data_new, x="Species", y="SepalLengthCm", hue="Species")

# %%
flower_data_new.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
plt.figure(figsize=(12, 7))
plt.subplot(2,2, 1)
sns.violinplot(data=flower_data_new, y="SepalLengthCm", x="Species")
plt.subplot(2,2, 2)
sns.violinplot(data=flower_data_new, y="SepalWidthCm", x="Species")
plt.subplot(2,2, 3)
sns.violinplot(data=flower_data_new, y="PetalLengthCm", x="Species")
plt.subplot(2,2, 4)
sns.violinplot(data=flower_data_new, y="PetalWidthCm", x="Species")
# Out:
# <Axes: xlabel='Species', ylabel='PetalWidthCm'>

# %%
sns.pairplot(data=flower_data_new, kind="scatter")

# %%
sns.pairplot(data=flower_data_new, hue="Species")

# %%
flower_data_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    category
# dtypes: category(1), float64(4)
# memory usage: 5.1 KB

# %%
fig = plt.gcf()
fig.set_size_inches(12, 6)
fig=sns.heatmap(flower_data_new.corr(numeric_only=True),annot=True,cmap='cubehelix',linewidths=1,linecolor='k',square=True,mask=False, vmin=-1, vmax=1,cbar_kws={"orientation": "vertical"},cbar=True)

# %%
flower_data_new.hist(edgecolor='black', linewidth=1.2)
fig=plt.gcf()
fig.set_size_inches(12,6)

# %%
sns.set(style="darkgrid")
sns.swarmplot(data=flower_data_new, x="Species", y="PetalLengthCm", hue="Species")
# Out:
# <Axes: xlabel='Species', ylabel='PetalLengthCm'>

# %%
sns.set(style="whitegrid")
fig=plt.gcf()
fig.set_size_inches(12,6)
sns.violinplot(data=flower_data_new, x="Species", y="PetalLengthCm", inner=None)
sns.swarmplot(data=flower_data_new, x="Species", y="PetalLengthCm", color="white", edgecolor="black")
# Out:
# <Axes: xlabel='Species', ylabel='PetalLengthCm'>

# %%
sns.lmplot(data=flower_data_new, x="PetalLengthCm", y="PetalWidthCm")

# %%
fg = sns.FacetGrid(data=flower_data_new, hue="Species")
fg.map(sns.kdeplot, "PetalLengthCm")
fg.add_legend()
plt.ioff
# Out:
# <function matplotlib.pyplot.ioff() -> 'ExitStack'>

# %%
sns.boxenplot(x='Species',y='SepalLengthCm',data=flower_data_new)
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %%
sub = flower_data_new[flower_data_new.Species=="Iris-setosa"]
sns.kdeplot(data=sub[["SepalLengthCm", "SepalWidthCm"]], shade=True)
# Out:
# <Axes: ylabel='Density'>

# %%
flower_data_new.plot.area(y=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'],alpha=0.4,figsize=(12, 6));

# %%
list1 = [flower_data_new[flower_data_new.Species == gen].SepalLengthCm for gen in flower_data_new.Species.cat.categories]
# print(list1)
labels = [gen for gen in flower_data_new.Species.cat.categories]
h = plt.hist(list1, bins=30, stacked=True, rwidth=1, label=labels)
plt.legend()
plt.show()
