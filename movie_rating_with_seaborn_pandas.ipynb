# %%
import pandas as pd

# %%
movies = pd.read_csv(r"C:\Users\ashif\datascience_notebooks\Movie-Rating.csv")

# %%
movies.shape
# Out:
# (559, 6)

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ["Film", "Genere", "CriticalRating", "AudienceRating", "BudgetMillions", "Year"]

# %%
movies.head()
# Out:
#                     Film     Genere  CriticalRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy              87              81
# 1            10,000 B.C.  Adventure               9              44
# 2             12 Rounds      Action              30              52
# 3              127 Hours  Adventure              93              84
# 4              17 Again      Comedy              55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.tail()
# Out:
#                 Film    Genere  CriticalRating  AudienceRating  \
# 554    Your Highness    Comedy              26              36
# 555  Youth in Revolt    Comedy              68              52
# 556           Zodiac  Thriller              89              73
# 557      Zombieland     Action              90              87
# 558        Zookeeper    Comedy              14              42
#
#      BudgetMillions  Year
# 554              50  2011
# 555              18  2009
# 556              65  2007
# 557              24  2009
# 558              80  2011

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genere          559 non-null    object
#  2   CriticalRating  559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
# Out:
#        CriticalRating  AudienceRating  BudgetMillions         Year
# count      559.000000      559.000000      559.000000   559.000000
# mean        47.309481       58.744186       50.236136  2009.152057
# std         26.413091       16.826887       48.731817     1.362632
# min          0.000000        0.000000        0.000000  2007.000000
# 25%         25.000000       47.000000       20.000000  2008.000000
# 50%         46.000000       58.000000       35.000000  2009.000000
# 75%         70.000000       72.000000       65.000000  2010.000000
# max         97.000000       96.000000      300.000000  2011.000000

# %%
movies.Year = movies.Year.astype('category')
movies.Film = movies.Film.astype('category')
movies.Genere = movies.Genere.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genere          559 non-null    category
#  2   CriticalRating  559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.describe()
# Out:
#        CriticalRating  AudienceRating  BudgetMillions
# count      559.000000      559.000000      559.000000
# mean        47.309481       58.744186       50.236136
# std         26.413091       16.826887       48.731817
# min          0.000000        0.000000        0.000000
# 25%         25.000000       47.000000       20.000000
# 50%         46.000000       58.000000       35.000000
# 75%         70.000000       72.000000       65.000000
# max         97.000000       96.000000      300.000000

# %%
movies.columns
# Out:
# Index(['Film', 'Genere', 'CriticalRating', 'AudienceRating', 'BudgetMillions',
#        'Year'],
#       dtype='object')

# %%
movies.head()
# Out:
#                     Film     Genere  CriticalRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy              87              81
# 1            10,000 B.C.  Adventure               9              44
# 2             12 Rounds      Action              30              52
# 3              127 Hours  Adventure              93              84
# 4              17 Again      Comedy              55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: category
# Categories (559, object): ['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours', ..., 'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper']

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
plt.boxplot(movies.BudgetMillions, data=movies, manage_ticks=True,  showmeans=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20186d30590>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20186d31ed0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20186d27a90>],
#  'medians': [<matplotlib.lines.Line2D at 0x20186d33710>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20186d44d90>],
#  'means': [<matplotlib.lines.Line2D at 0x20186d44250>]}

# %%
plt.plot(movies.BudgetMillions[:10], movies.AudienceRating[:10])
plt.show()

# %%
movies.head()
# Out:
#                     Film     Genere  CriticalRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy              87              81
# 1            10,000 B.C.  Adventure               9              44
# 2             12 Rounds      Action              30              52
# 3              127 Hours  Adventure              93              84
# 4              17 Again      Comedy              55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#joint plot
vis1 = sns.jointplot(data=movies, x=movies.CriticalRating, y=movies.AudienceRating)

# %%
sns.set_style('darkgrid')
vis1 = sns.jointplot(data=movies, x=movies.CriticalRating, y=movies.AudienceRating, kind='reg')

# %%
sns.set_style('whitegrid')
vis1 = sns.jointplot(data=movies, x=movies.CriticalRating, y=movies.AudienceRating, kind='reg')

# %%
vis1 = sns.jointplot(data=movies, x=movies.CriticalRating, y=movies.AudienceRating, kind='hex')

# %%
vis1 = sns.jointplot(data=movies, x=movies.CriticalRating, y=movies.AudienceRating, kind='hist')

# %%
sns.set_style('darkgrid')
vis1 = sns.jointplot(data=movies, x=movies.CriticalRating, y=movies.AudienceRating, kind='kde', bins=20)

# %%
vis1 = sns.jointplot(data=movies, x=movies.CriticalRating, y=movies.AudienceRating, kind='resid')

# %%
vis2 = sns.distplot(x=movies.AudienceRating)

# %%
vis2 = sns.distplot(x=movies.AudienceRating, bins=15)

# %%
vis2 = sns.distplot(x=movies.CriticalRating, bins=15)

# %%
vis3 = plt.hist(x=movies.AudienceRating)

# %%
vis4 = plt.hist(x=movies.CriticalRating, bins=20)

# %%
#LM plot
vis5 = sns.lmplot(data=movies, x='CriticalRating', y='AudienceRating')

# %%
vis5 = sns.lmplot(data=movies, x='CriticalRating', y='AudienceRating', fit_reg=False)

# %%
movies.head()
# Out:
#                     Film     Genere  CriticalRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy              87              81
# 1            10,000 B.C.  Adventure               9              44
# 2             12 Rounds      Action              30              52
# 3              127 Hours  Adventure              93              84
# 4              17 Again      Comedy              55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
vis5 = sns.lmplot(data=movies, x='CriticalRating', y='AudienceRating', fit_reg=False, hue='Genere')

# %%
vis6 = sns.lmplot(data=movies, x="BudgetMillions", y="AudienceRating", hue="Genere")

# %%
movies[['Genere']]
# Out:
#         Genere
# 0       Comedy
# 1    Adventure
# 2       Action
# 3    Adventure
# 4       Comedy
# ..         ...
# 554     Comedy
# 555     Comedy
# 556   Thriller
# 557     Action
# 558     Comedy
#
# [559 rows x 1 columns]

# %%
genere = movies['Genere']
filter_romance_movies = movies[genere == "Romance"]
filter_romance_movies
# Out:
#                                     Film   Genere  CriticalRating  \
# 16                   Across the Universe  Romance              54
# 42                               Beastly  Romance              19
# 78                   Crazy, Stupid, Love  Romance              78
# 108                           Duplicity   Romance              64
# 136                Friends With Benefits  Romance              71
# 201                            Jane Eyre  Romance              85
# 208                      Just Go With It  Romance              19
# 244                    Midnight in Paris  Romance              93
# 250                          Monte Carlo  Romance              38
# 255                     Music and Lyrics  Romance              63
# 266                       New Year's Eve  Romance               8
# 284                              One Day  Romance              37
# 290                      P.S. I Love You  Romance              21
# ...

# %%
filter_romance_movies[filter_romance_movies['CriticalRating']==filter_romance_movies["CriticalRating"].min()]
# Out:
#                    Film   Genere  CriticalRating  AudienceRating  \
# 354  Something Borrowed  Romance               0               0
#
#      BudgetMillions  Year
# 354              35  2011

# %%
plt.hist(movies.BudgetMillions)
# Out:
# (array([237., 162.,  75.,  28.,  17.,  20.,  13.,   3.,   3.,   1.]),
#  array([  0.,  30.,  60.,  90., 120., 150., 180., 210., 240., 270., 300.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(movies[movies.Genere == "Drama"].BudgetMillions)
# Out:
# (array([25., 40., 18.,  8.,  6.,  2.,  1.,  0.,  0.,  1.]),
#  array([  0.,  15.,  30.,  45.,  60.,  75.,  90., 105., 120., 135., 150.]),
#  <BarContainer object of 10 artists>)

# %%
r_movies=movies[movies.Genere=='Romance']
min_budget = r_movies["BudgetMillions"].min()
max_budget = r_movies["BudgetMillions"].max()
print(min_budget, max_budget)
print(r_movies[r_movies.BudgetMillions == min_budget])
print(r_movies[r_movies.BudgetMillions == max_budget])
# Out:
# 0 110
#           Film   Genere  CriticalRating  AudienceRating  BudgetMillions  Year
# 201  Jane Eyre  Romance              85              77               0  2011
#                         Film   Genere  CriticalRating  AudienceRating  \
# 507  Twilight: Breaking Dawn  Romance              26              68
#
#      BudgetMillions  Year
# 507             110  2011

# %%
movies['Genere'].unique()
# Out:
# ['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance', 'Thriller']
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
plt.hist(movies[movies.Genere=='Comedy'].BudgetMillions, bins=20)
plt.hist(movies[movies.Genere=='Adventure'].BudgetMillions, bins=20)
plt.hist(movies[movies.Genere=='Action'].BudgetMillions, bins=20)
plt.hist(movies[movies.Genere=='Horror'].BudgetMillions, bins=20)
plt.hist(movies[movies.Genere=='Drama'].BudgetMillions, bins=20)
plt.hist(movies[movies.Genere=='Romance'].BudgetMillions, bins=20)
plt.hist(movies[movies.Genere=='Thriller'].BudgetMillions, bins=20)
plt.legend(movies.Genere)
plt.show()

# %%
plt.hist([movies[movies.Genere=='Comedy'].BudgetMillions,
          movies[movies.Genere=='Adventure'].BudgetMillions, 
          movies[movies.Genere=='Action'].BudgetMillions, 
          movies[movies.Genere=='Horror'].BudgetMillions], bins=20, stacked=True)
plt.legend(movies.Genere)
plt.show()

# %%
movies_gen_with_budget = []
for gen in movies.Genere.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
vis5 = sns.lmplot(data=movies, x='CriticalRating', y='AudienceRating', fit_reg=False, hue='Genere', aspect=1)

# %%
movies.head()
# Out:
#                     Film     Genere  CriticalRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy              87              81
# 1            10,000 B.C.  Adventure               9              44
# 2             12 Rounds      Action              30              52
# 3              127 Hours  Adventure              93              84
# 4              17 Again      Comedy              55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
vis5 = sns.kdeplot(data=movies, x="CriticalRating", y="AudienceRating")

# %%
vis5 = sns.kdeplot(data=movies, x="CriticalRating", y="AudienceRating")

# %%
vis5 = sns.kdeplot(data=movies, x="CriticalRating", y="AudienceRating", hue="Genere")

# %%
vis5 = sns.kdeplot(data=movies, x="CriticalRating", y="AudienceRating", common_grid=True, fill=True)

# %%
vis5 = sns.kdeplot(data=movies, x="CriticalRating", y="AudienceRating", common_grid=True, fill=True, cmap='Reds')

# %%
vis5 = sns.kdeplot(data=movies, x="CriticalRating", y="AudienceRating", common_grid=True, fill=True, cmap='Reds', shade_lowest=False)

# %%
vis5 = sns.kdeplot(data=movies,  y="AudienceRating", x="CriticalRating", common_grid=True, fill=True, cmap='Greens')

# %%
vis5 = sns.kdeplot(data=movies,  y="AudienceRating", x="CriticalRating", cmap='Greens', shade_lowest=True)

# %%
vis5 = sns.kdeplot(data=movies, x="CriticalRating", y="AudienceRating", common_grid=True, fill=True, cumulative=True)
vis5
# Out:
# <Axes: xlabel='CriticalRating', ylabel='AudienceRating'>

# %%
vis6 = sns.kdeplot(data=movies, x='BudgetMillions', y='AudienceRating', low_shade=True)

# %%
vis6 = sns.kdeplot(data=movies, x='BudgetMillions', y='AudienceRating', fill=True)

# %%
vis6 = sns.kdeplot(data=movies, x='BudgetMillions', y='AudienceRating', fill=True, hue='Genere', low_shade=True)

# %%
vis6 = sns.kdeplot(data=movies, x='BudgetMillions', y='AudienceRating', fill=True, hue='Genere', low_shade=True)

# %%
vis6 = sns.kdeplot(movies.BudgetMillions)

# %%
vis6 = sns.kdeplot(movies.AudienceRating)

# %%
vis6 = sns.kdeplot(x=movies.BudgetMillions, y=movies.CriticalRating)

# %%
#subplots
vis7 = plt.subplots(3,3)

# %%
vis7 = plt.subplots(2,2, figsize=(5,4))

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genere          559 non-null    category
#  2   CriticalRating  559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
fig, axes = plt.subplots(1,2, figsize=(5,4))
print(type(movies["CriticalRating"]))
kd1 = sns.kdeplot(x=movies.CriticalRating, y=movies.AudienceRating, ax=axes[0])
kd2 = sns.kdeplot(x=movies.BudgetMillions, y=movies.AudienceRating, ax=axes[1])
# Out:
# <class 'pandas.core.series.Series'>

# %%
fig, axes = plt.subplots(2,2, figsize=(12,8))
kde1 = sns.kdeplot(x=movies.BudgetMillions, y=movies.CriticalRating, hue=movies.Genere, fill=True, ax=axes[0,0])
kde2 = sns.kdeplot(x=movies.BudgetMillions, y=movies.AudienceRating, hue=movies.Genere, fill=True, ax=axes[0,1])
kde3 = sns.kdeplot(x=movies.CriticalRating, y=movies.AudienceRating, hue=movies.Genere, fill=True, ax=axes[1,0])
kde4 = sns.kdeplot(x=movies.BudgetMillions, y=movies.AudienceRating, hue=movies.Genere, fill=True, ax=axes[1,1])

# %%
#Box plots
bx1 = sns.boxplot(y=movies.AudienceRating, x=movies.Genere)

# %%
yv1 = sns.violinplot(data=movies, x="Genere", y='AudienceRating')

# %%
yv1 = sns.violinplot(data=movies, x="Genere", y='CriticalRating')

# %%
yv2 = sns.boxplot(data=movies[movies.Genere=="Drama"], x="Year", y="AudienceRating")

# %%
movies.head()
# Out:
#                     Film     Genere  CriticalRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy              87              81
# 1            10,000 B.C.  Adventure               9              44
# 2             12 Rounds      Action              30              52
# 3              127 Hours  Adventure              93              84
# 4              17 Again      Comedy              55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
yv3 = sns.boxplot(data=movies[movies.Genere=="Comedy"], x="Year", y="CriticalRating")

# %%
#factgrid
fg = sns.FacetGrid(data=movies,row="Genere", col="Year", hue="Genere")
# sv = plt.scatter(movies.AudienceRating, movies.CriticalRating)
fg.map(plt.scatter, "CriticalRating", "AudienceRating")

# %%
sns.set_style(style="darkgrid")
fg1 = sns.FacetGrid(data=movies, row="Genere", col="Year", hue="Genere")
fg1.map(sns.scatterplot, "BudgetMillions", "AudienceRating")

# %%
fg2 = sns.FacetGrid(data=movies, row="Genere", col="Year", hue="Genere")
fg2.map(sns.histplot, 'CriticalRating', "AudienceRating")

# %%
fg1 = sns.FacetGrid(data=movies, row="Genere", col="Year", hue="Genere")
fg1.map(sns.histplot, "BudgetMillions")

# %%
fg3 = sns.FacetGrid(data=movies, row="Genere", col="Year", hue="Genere")
kwargs = dict(s=50, linewidth=0.5, edgecolor="black")
fg3.map(sns.scatterplot, "CriticalRating","AudienceRating", **kwargs)

# %%
sns.set_style('dark',{'axes.facecolor':'black'})
fig, axes = plt.subplots(2,2, figsize=(12,8))
k1 = sns.kdeplot(x=movies.BudgetMillions, y=movies.CriticalRating, shade=True, cmap = 'inferno', ax=axes[0,0])
k11 = sns.kdeplot(x=movies.BudgetMillions, y=movies.CriticalRating, cmap = 'cool', ax=axes[0,0])
k2 = sns.kdeplot(x=movies.BudgetMillions, y=movies.AudienceRating, shade=True, cmap='inferno', ax=axes[0,1])
k22 = sns.kdeplot(x=movies.BudgetMillions, y=movies.AudienceRating, cmap='cool', ax=axes[0,1])
k1.set(xlim=(-20, 160))
k2.set(xlim=(-20, 160))
z=sns.violinplot(data=movies[movies.Genere == 'Drama'], x='Year', y='CriticalRating', ax=axes[1,0])
k3 = sns.kdeplot(x=movies.CriticalRating, y=movies.AudienceRating, shade=True, cmap='Reds', ax=axes[1,1])
k4 = sns.kdeplot(x=movies.CriticalRating, y=movies.AudienceRating, cmap="gist_gray_r", ax=axes[1,1])
plt.show()
