# %%
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
heart_disease_stats = pd.read_csv(r"C:\Users\ashif\datascience_notebooks\heart.csv")
heart_disease_stats.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
heart_disease_stats.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
heart_disease_stats.target.count()
# Out:
# 303

# %%
heart_disease_stats.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
heart_disease_stats.shape
# Out:
# (303, 14)

# %%
heart_disease_stats.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
heart_disease_stats["target"].nunique()
# Out:
# 2

# %%
heart_disease_stats["target"].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
heart_disease_stats["target"].value_counts() #to find count of patients with and without heart-attack (0- no-attack,  1-heart-attack)
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
f, ax = plt.subplots(figsize=(8,6))
ax = sns.countplot(x="target", data=heart_disease_stats)
plt.show()

# %%
heart_disease_stats.groupby("sex")["target"].count()
# Out:
# sex
# 0     96
# 1    207
# Name: target, dtype: int64

# %%
sns.countplot(x="sex", data=heart_disease_stats)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
heart_disease_stats.groupby("sex")["target"].value_counts()
# Out:
# sex  target
# 0    1          72
#      0          24
# 1    0         114
#      1          93
# Name: count, dtype: int64

# %%
f, ax = plt.subplots(figsize=(8,6))
ax = sns.countplot( data=heart_disease_stats, x="sex")
plt.show()

# %%
ax = sns.catplot(data=heart_disease_stats, x="target", col="sex", kind="count", height=5, aspect=1)

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(y="target", hue="sex", data=heart_disease_stats,)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 2
#       1 f, ax = plt.subplots(figsize=(8, 6))
# ----> 2 ax = sns.countplot(y="target", hue="sex", data=heart_disease_stats,)
#       3 plt.show()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# ...

# %%
ax = sns.countplot(data=heart_disease_stats,x="target", palette="Set3")
plt.show()

# %%
ax = sns.countplot(data=heart_disease_stats,x="target", facecolor=(0,0,0,0), linewidth=5, edgecolor=sns.color_palette("dark", 3))
plt.show()

# %%
sns.countplot(data=heart_disease_stats, x=heart_disease_stats.target, hue=heart_disease_stats.sex)

# %%
f, ax= plt.subplots(figsize=(10,7))
ax = sns.countplot(data=heart_disease_stats, x=heart_disease_stats.target, hue=heart_disease_stats.fbs)
plt.show()

# %%
sns.countplot(data=heart_disease_stats, x=heart_disease_stats.target, hue=heart_disease_stats.exang)

# %%
correlation = heart_disease_stats.corr()

# %%
correlation["target"].sort_values(ascending=False)

# %%
heart_disease_stats.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
heart_disease_stats.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease_stats.target.nunique()
# Out:
# 2

# %%
heart_disease_stats.target.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
heart_disease_stats.target.count()
# Out:
# 303

# %%
heart_disease_stats.target.value_counts()
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
sns.countplot(data=heart_disease_stats, x="target")
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
heart_disease_stats["sex"].value_counts()
# Out:
# sex
# 1    207
# 0     96
# Name: count, dtype: int64

# %%
sns.countplot(data=heart_disease_stats, x="sex")
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
heart_disease_stats.groupby("sex").target.value_counts()
# Out:
# sex  target
# 0    1          72
#      0          24
# 1    0         114
#      1          93
# Name: count, dtype: int64

# %%
sns.countplot(data=heart_disease_stats, x="sex", hue="target")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 sns.countplot(data=heart_disease_stats, x="sex", hue="target")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:767, in _CategoricalPlotter.annotate_axes(self, ax)
# ...

# %%
# plt.plot(heart_disease_stats)
f, ax = plt.subplots(nrows=2,ncols=2, figsize=(10,8))
sns.scatterplot(data=heart_disease_stats, y="sex", hue="target", ax=ax[0,0])
sns.barplot(data=heart_disease_stats, ax=ax[0,1])
sns.boxenplot(data=heart_disease_stats, ax=ax[1,0])
sns.distplot(x=heart_disease_stats, ax=ax[1,1])              
plt.show()

# %%
f, ax = plt.subplots(figsize=(10,8))
ax = sns.countplot(data=heart_disease_stats, x="target")
ax = sns.countplot(data=heart_disease_stats, y="sex", hue="target")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[83], line 3
#       1 f, ax = plt.subplots(figsize=(10,8))
#       2 ax = sns.countplot(data=heart_disease_stats, x="target")
# ----> 3 ax = sns.countplot(data=heart_disease_stats, y="sex", hue="target")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# ...

# %%
heart_disease_stats.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease_stats.fbs.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
heart_disease_stats.restecg.unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %%
heart_disease_stats.exang.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
heart_disease_stats.ca.unique()
# Out:
# array([0, 2, 1, 3, 4], dtype=int64)

# %%
sns.countplot(x=heart_disease_stats.fbs,hue=heart_disease_stats.target)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 sns.countplot(x=heart_disease_stats.fbs,hue=heart_disease_stats.target)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:767, in _CategoricalPlotter.annotate_axes(self, ax)
# ...

# %%
heart_disease_stats.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
f, ax= plt.subplots(figsize=(10,6))
ax = sns.countplot(data=heart_disease_stats, x="target", hue="exang")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[91], line 2
#       1 f, ax= plt.subplots(figsize=(10,6))
# ----> 2 ax = sns.countplot(data=heart_disease_stats, x="target", hue="exang")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# ...

# %%
heart_disease_stats.groupby("exang").target.value_counts()
# Out:
# exang  target
# 0      1         142
#        0          62
# 1      0          76
#        1          23
# Name: count, dtype: int64

# %%
correlation = heart_disease_stats.corr()

# %%
correlation
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
correlation["target"]
# Out:
# age        -0.225439
# sex        -0.280937
# cp          0.433798
# trestbps   -0.144931
# chol       -0.085239
# fbs        -0.028046
# restecg     0.137230
# thalach     0.421741
# exang      -0.436757
# oldpeak    -0.430696
# slope       0.345877
# ca         -0.391724
# thal       -0.344029
# target      1.000000
# Name: target, dtype: float64

# %%
correlation["target"].sort_values(ascending=False)
# Out:
# target      1.000000
# cp          0.433798
# thalach     0.421741
# slope       0.345877
# restecg     0.137230
# fbs        -0.028046
# chol       -0.085239
# trestbps   -0.144931
# age        -0.225439
# sex        -0.280937
# thal       -0.344029
# ca         -0.391724
# oldpeak    -0.430696
# exang      -0.436757
# Name: target, dtype: float64

# %%
heart_disease_stats["cp"]
# Out:
# 0      3
# 1      2
# 2      1
# 3      1
# 4      0
#       ..
# 298    0
# 299    3
# 300    0
# 301    0
# 302    1
# Name: cp, Length: 303, dtype: int64

# %%
heart_disease_stats["cp"].nunique()
# Out:
# 4

# %%
heart_disease_stats["cp"].value_counts()
# Out:
# cp
# 0    143
# 2     87
# 1     50
# 3     23
# Name: count, dtype: int64

# %%
f,ax = plt.subplots(figsize=(10,6))
ax = sns.countplot(data=heart_disease_stats,x="cp")
plt.show()

# %%
sns.countplot(data=heart_disease_stats, x="cp", hue="target")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 sns.countplot(data=heart_disease_stats, x="cp", hue="target")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:767, in _CategoricalPlotter.annotate_axes(self, ax)
# ...

# %%
f, ax = plt.subplots(figsize=(10,5))
ax = sns.catplot(data=heart_disease_stats, x="target", col="cp", kind="count", height=8, aspect=1)
plt.show()

# %%
heart_disease_stats["thalach"].nunique()
# Out:
# 91

# %%
heart_disease_stats["thalach"].value_counts()
# Out:
# thalach
# 162    11
# 160     9
# 163     9
# 152     8
# 173     8
#        ..
# 202     1
# 184     1
# 121     1
# 192     1
# 90      1
# Name: count, Length: 91, dtype: int64

# %%
# f,ax = plt.subplots(figsize=(10,6))
ax=sns.displot(x=heart_disease_stats["thalach"], bins=10)
plt.show()

# %%
x = heart_disease_stats["thalach"]
x = pd.Series(x, name="thalach variable")
sns.displot(x, bins=10)
plt.show()

# %%
x = heart_disease_stats["thalach"]
x = pd.Series(x, name="thalach variable")
sns.displot(x, bins=10)
plt.show()

# %%
x = heart_disease_stats["thalach"]
x = pd.Series(x, name="thalach variable")
sns.kdeplot(x)
plt.show()

# %%
x = heart_disease_stats["thalach"]
x = pd.Series(x, name="thalach variable")
sns.kdeplot(x, shade=True, color='r')
plt.show()

# %%
x = heart_disease_stats.thalach
sns.distplot(x, kde=False, rug=True, bins=10)
plt.show()

# %%
sns.stripplot(data=heart_disease_stats, x="target", y="thalach", hue="target")
# Out:
# <Axes: xlabel='target', ylabel='thalach'>

# %%
sns.stripplot(data=heart_disease_stats, x="target", y="thalach", jitter=0.01, hue="target")
# Out:
# <Axes: xlabel='target', ylabel='thalach'>

# %%
sns.boxplot(data=heart_disease_stats,x="target",y="thalach")
# Out:
# <Axes: xlabel='target', ylabel='thalach'>

# %%
correlation
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
plt.title("correlation heatmap of heart disease dataset")
a = sns.heatmap(correlation)

# %%
plt.figure(figsize=(16,12))
plt.title("correlation heatmap of heart disease dataset")
a = sns.heatmap(correlation, square=True, annot=True, fmt='.2f', linecolor='white')
a.set_xticklabels(a.get_xticklabels(), rotation=90)
a.set_yticklabels(a.get_yticklabels(), rotation=90)
plt.show()

# %%
num_var = ["age", "trestbps", "chol", "thalach", "oldpeak", "target"]
sns.pairplot(heart_disease_stats[num_var], kind='scatter', diag_kind='hist')
plt.show()

# %%
heart_disease_stats["age"].nunique()
# Out:
# 41

# %%
heart_disease_stats['age'].describe()
# Out:
# count    303.000000
# mean      54.366337
# std        9.082101
# min       29.000000
# 25%       47.500000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
sns.displot(heart_disease_stats['age'], bins=10, rug=True)

# %%
sns.stripplot(data=heart_disease_stats, x="target", y="age", hue="target")
# Out:
# <Axes: xlabel='target', ylabel='age'>

# %%
sns.boxplot(data=heart_disease_stats, x="target", y="age", hue="target")
# Out:
# <Axes: xlabel='target', ylabel='age'>

# %%
sns.scatterplot(data=heart_disease_stats, x="age", y="trestbps", hue="target")
# Out:
# <Axes: xlabel='age', ylabel='trestbps'>

# %%
sns.regplot(data=heart_disease_stats, x="age", y="trestbps")
# Out:
# <Axes: xlabel='age', ylabel='trestbps'>

# %%
sns.scatterplot(data=heart_disease_stats, x="age", y="chol")
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
sns.regplot(data=heart_disease_stats, x="age", y="chol")
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
sns.scatterplot(data=heart_disease_stats, x="chol", y="thalach")
# Out:
# <Axes: xlabel='chol', ylabel='thalach'>

# %%
sns.regplot(data=heart_disease_stats, x="chol", y="thalach")
# Out:
# <Axes: xlabel='chol', ylabel='thalach'>

# %%
heart_disease_stats.isnull()
# Out:
#        age    sex     cp  trestbps   chol    fbs  restecg  thalach  exang  \
# 0    False  False  False     False  False  False    False    False  False
# 1    False  False  False     False  False  False    False    False  False
# 2    False  False  False     False  False  False    False    False  False
# 3    False  False  False     False  False  False    False    False  False
# 4    False  False  False     False  False  False    False    False  False
# ..     ...    ...    ...       ...    ...    ...      ...      ...    ...
# 298  False  False  False     False  False  False    False    False  False
# 299  False  False  False     False  False  False    False    False  False
# 300  False  False  False     False  False  False    False    False  False
# 301  False  False  False     False  False  False    False    False  False
# 302  False  False  False     False  False  False    False    False  False
#
#      oldpeak  slope     ca   thal  target
# ...

# %%
heart_disease_stats.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
assert pd.notnull(heart_disease_stats).all().all()

# %%
assert (heart_disease_stats>=0).all().all()

# %%
heart_disease_stats.age.describe()
# Out:
# count    303.000000
# mean      54.366337
# std        9.082101
# min       29.000000
# 25%       47.500000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
sns.boxplot(x=heart_disease_stats.age)
# Out:
# <Axes: xlabel='age'>

# %%
heart_disease_stats.trestbps.describe()
# Out:
# count    303.000000
# mean     131.623762
# std       17.538143
# min       94.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      200.000000
# Name: trestbps, dtype: float64

# %%
sns.boxplot(x=heart_disease_stats.trestbps)
# Out:
# <Axes: xlabel='trestbps'>

# %%
heart_disease_stats.chol.describe()
# Out:
# count    303.000000
# mean     246.264026
# std       51.830751
# min      126.000000
# 25%      211.000000
# 50%      240.000000
# 75%      274.500000
# max      564.000000
# Name: chol, dtype: float64

# %%
sns.boxplot(x=heart_disease_stats.chol)
# Out:
# <Axes: xlabel='chol'>

# %%
heart_disease_stats.thalach.describe()
# Out:
# count    303.000000
# mean     149.646865
# std       22.905161
# min       71.000000
# 25%      133.500000
# 50%      153.000000
# 75%      166.000000
# max      202.000000
# Name: thalach, dtype: float64

# %%
sns.boxplot(x=heart_disease_stats.thalach)
# Out:
# <Axes: xlabel='thalach'>

# %%
sns.boxplot(x=heart_disease_stats.oldpeak)
# Out:
# <Axes: xlabel='oldpeak'>
